# %% [markdown]
# ## Part 2.1 - Correcting & Enriching the dataset
#
# The notebook is split into two parts:
#
# **Part 2.1.1:** Will correct any mistake found in the dataset from the previous notebook versions and will add a new column to the dataset. The new column will be the official TMDB id of each movie. In the same part new columns will be added to further support the *training* and the *accuracy* of the recommendation algorithm. The new columns currently added into the dataset to enrich the written text for each movie are:
# * Overview text from TMDB API
# * Instead of one review we will now use 3 reviews per movie were possible.
#
# **Part 2.1.2:** Will be used to add any additional movie (rows) into the dataset to contain more genres or movies. One way to achieve this is using the TMDB ids collected from part 2.1.1 and exploit the content of movies from the TMDB API.

# %% [markdown]
# #### -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --

# %% [markdown]
# ### Section 2.1.1
# To follow through this section you are advised to read the comments on top of each code block.

# %%
"""
Import the two csv files that contain the movie titles and the movie TMDB ids. 
This dataset will be merged with the already created and cleaned dataset from part 2 to bring the registered TMDB id per movie.
"""
import pandas as pd
import joblib
import os
import re
movie_links=pd.read_csv('links.csv')
movie_movies=pd.read_csv('movies.csv')
movie_merged=movie_movies.merge(movie_links, how='inner', on='movieId')
assert movie_links.shape[0]==movie_movies.shape[0]==movie_merged.shape[0]

exp = r'\(\d\d\d\d.'
pattern = '\((\d{4})\)'
movie_merged['year'] =movie_merged.title.str.extract(pattern, expand=False) #False returns a series
movie_merged['title']=movie_merged['title'].apply(lambda x: re.sub(exp,"",x).strip())
movie_merged['title']=movie_merged['title'].str.replace(r'(.*?),?\s*(The|A|An|Les)?(?=\s*\(.*\)\s*|$).*', r'\2 \1')
movie_merged['title']=movie_merged['title'].str.strip().reset_index(drop=True)
movie_merged.dropna(inplace=True)
# Out:
# c:\users\spano\miniconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\spano\miniconda3\lib\site-packages\numpy\.libs\libopenblas.JPIJNSWNNAN3CE6LLI5FWSPHUT2VXMTH.gfortran-win_amd64.dll
# c:\users\spano\miniconda3\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# <ipython-input-3-6bf125a2853d>:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   movie_merged['title']=movie_merged['title'].str.replace(r'(.*?),?\s*(The|A|An|Les)?(?=\s*\(.*\)\s*|$).*', r'\2 \1')

# %%
movie_merged[movie_merged["title"].isin(["Babylon"])]
# Out:
#        movieId    title genres  imdbId   tmdbId  year
# 17222    86657  Babylon  Drama   80406  57082.0  1981

# %%
movie_merged.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  imdbId   tmdbId  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  114709    862.0  1995
# 1                   Adventure|Children|Fantasy  113497   8844.0  1995
# 2                               Comedy|Romance  113228  15602.0  1995
# 3                         Comedy|Drama|Romance  114885  31357.0  1995
# 4                                       Comedy  113041  11862.0  1995

# %%
"""
python package 1: tmdbv3apic
python package 2: tmdbsimple
"""
from tmdbv3api import TMDb
from tmdbv3api import Movie
from tmdbv3api import Discover

tmdb = TMDb()
tmdb.api_key = 'bc519c5e728ee16367446f4bd61ef2f5'
tmdb.language = 'en'
tmdb.debug = True

movie=Movie()
m=movie.details(movie_id=602262)
print(m.keys())
print(m.genres)
print(m.title)
print(m.overview)
# discover = Discover()
# movie = discover.discover_movies({
#     'primary_release_date.gte': '2015-01-01'
# })
# Out:
# dict_keys(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count', 'videos', 'trailers', 'images', 'casts', 'translations', 'keywords', 'release_dates'])
# [{'id': 35, 'name': 'Comedy'}, {'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}, {'id': 10770, 'name': 'TV Movie'}]
# Dead Husbands
# Dr. Carter Elson is a man who finds a list of men's names among his wife Alex's possessions. When Carter discovers his own name at the bottom of the list, and that some of the other names are those of dead men, he confides in his friend/agent Betty. Time is ticking as they try and figure out what the list means before his name reaches the top. Alex, a small town girl who marries the up-and-coming doctor as an entry to the social-climbing world she always coveted, is frustrated when obstacles are placed in her path. She meets two other "unhappy wives," played by Sonja Smits and Donna Pescow, and discovers a way out that may be the answer to all of her prayers. The women conspire to 'shorten the list!'

# %%
movie.details(165911)["imdb_id"]
# Out:
# 'tt0187809'

# %%
"""
Import the dataset. The version of the dataset below is derived from part 2.
"""
dataset=joblib.load(os.path.join(os.getcwd(),"dataset_part_2_cleaned_of_redundant_genres_18022021.pkl"))

# %%
"""Print the total na values accross all columns"""
dataset.isna().sum()
# Out:
# title                0
# genres               0
# rating               0
# imdb_url             0
# reviews_url          0
# actors               0
# plot                 0
# imdb_rating          0
# director             0
# reviews              0
# year               175
# sentiment_value      0
# movie_features       0
# reduced_genres       0
# dtype: int64

# %%
"""Drop the movies with na values found in column year."""
dataset.dropna(inplace=True)
dataset.shape
# Out:
# (48947, 14)

# %%
"""
Merge the dataset from part 2 with the downloaded dataset from Groplens that contains the TMDB id per movie.
This code block is the starting point of enriching movies with additional content. 
Using their registered TMDB id we can extract information from the TDMB database API.
"""
dataset_tmdbid=dataset.merge(movie_merged[['title', 'year', 'tmdbId']], how='left', on=['title', 'year'], indicator=True)
dataset_tmdbid_rduplicates=dataset_tmdbid.sort_values('year').drop_duplicates(['title', 'year'], keep='last').sort_index().reset_index(drop=True)
dataset_tmdbid_rduplicates=dataset_tmdbid_rduplicates.reset_index(drop=True)
print(dataset_tmdbid.shape)
print(dataset_tmdbid_rduplicates.shape)
# Out:
# (49108, 16)
# (48875, 16)

# %%
"""
Print the dataset rows with no tmbd id. 
For the rows printed we didn't locate an existing TMDB id from the Grouplens dataset
"""
dataset_tmdbid_rduplicates[dataset_tmdbid_rduplicates['_merge']!='both']
# Out:
#                                                    title  \
# 700                                             Halfmoon
# 1626                                  The Sadness of Sex
# 1658                                    Follow the Bitch
# 2079                                          The Master
# 3002                                            Creature
# 4950                                          Luminarias
# 5337                                       The Dogwalker
# 5508                                    Faces of Death 5
# 6892                                Prisoner of Paradise
# 7227                                           Love Life
# 8793                                       The Decalogue
# 9166                                           Idle Mist
# 13251                                      Dead Husbands
# 14355                                         Red Chapel
# 14552                       Hellsing Ultimate OVA Series
# 14816               The Cross: The Arthur Blessitt Story
# 23621              1.0  Shakespeare's Globe: Henry V Jamie Parker Brid...
#
#                          reduced_genres  tmdbId     _merge
# 700                             [Drama]     NaN  left_only
# 1626                            [Drama]     NaN  left_only
# 1658                           [Comedy]     NaN  left_only
# 2079                           [Action]     NaN  left_only
# 3002                      [Documentary]     NaN  left_only
# 4950                  [Comedy, Romance]     NaN  left_only
# 5337                            [Drama]     NaN  left_only
# 5508              [Documentary, Horror]     NaN  left_only
# 6892                      [Documentary]     NaN  left_only
# 7227                  [Comedy, Romance]     NaN  left_only
# 8793            [Crime, Drama, Romance]     NaN  left_only
# 9166           [Crime, Horror, Mystery]     NaN  left_only
# 13251          [Comedy, Drama, Romance]     NaN  left_only
# 14355             [Comedy, Documentary]     NaN  left_only
# 14552       [Action, Animation, Horror]     NaN  left_only
# 14816                     [Documentary]     NaN  left_only
# 15330                     [Documentary]     NaN  left_only
# 15353          [Comedy, Crime, Mystery]     NaN  left_only
# 15484                     [Documentary]     NaN  left_only
# 15554             [Animation, Children]     NaN  left_only
# 15934                  [Comedy, Horror]     NaN  left_only
# 16226                     [Documentary]     NaN  left_only
# 16311                   [Comedy, Drama]     NaN  left_only
# 16536                     [Documentary]     NaN  left_only
# 16764                     [Documentary]     NaN  left_only
# 17676                          [Comedy]     NaN  left_only
# 17836                       [Animation]     NaN  left_only
# 17949               [Action, Animation]     NaN  left_only
# 18300                           [Crime]     NaN  left_only
# 18718                     [Documentary]     NaN  left_only
# 18874        [Animation, Comedy, Drama]     NaN  left_only
# 19057                     [Documentary]     NaN  left_only
# 20901                          [Comedy]     NaN  left_only
# 20913                     [Documentary]     NaN  left_only
# 21088                 [Comedy, Romance]     NaN  left_only
# 21099                           [Drama]     NaN  left_only
# 21149                     [Documentary]     NaN  left_only
# 21150                     [Documentary]     NaN  left_only
# 21157                     [Documentary]     NaN  left_only
# 21162                     [Documentary]     NaN  left_only
# 21222                           [Drama]     NaN  left_only
# 21281       [Action, Animation, Comedy]     NaN  left_only
# 21454                      [Drama, War]     NaN  left_only
# 21520                [Musical, Western]     NaN  left_only
# 21959                 [Comedy, Musical]     NaN  left_only
# 22372                          [Comedy]     NaN  left_only
# 22427                    [Crime, Drama]     NaN  left_only
# 22611  [Adventure, Animation, Children]     NaN  left_only
# 22632         [Drama, Horror, Thriller]     NaN  left_only
# 22818                           [Drama]     NaN  left_only
# 22902                          [Comedy]     NaN  left_only
# 23073                     [Documentary]     NaN  left_only
# 23177                     [Documentary]     NaN  left_only
# 23428                 [Action, Mystery]     NaN  left_only
# 23621                           [Drama]     NaN  left_only

# %%
"""
Get the index of the movies that have an NA tmdbId after the join with the Grouplens dataset.
Those 55 indexes below should be reviewed one by one and apply necessary actions. 
Either remove them from the dataset or replace their tmdbId with the correct one from the TMDB API.
"""
list_values=dataset_tmdbid_rduplicates['title'].index[dataset_tmdbid_rduplicates['tmdbId'].isna()]
list_values
# Out:
# Int64Index([  700,  1626,  1658,  2079,  3002,  4950,  5337,  5508,  6892,
#              7227,  8793,  9166, 13251, 14355, 14552, 14816, 15330, 15353,
#             15484, 15554, 15934, 16226, 16311, 16536, 16764, 17676, 17836,
#             17949, 18300, 18718, 18874, 19057, 20901, 20913, 21088, 21099,
#             21149, 21150, 21157, 21162, 21222, 21281, 21454, 21520, 21959,
#             22372, 22427, 22611, 22632, 22818, 22902, 23073, 23177, 23428,
#             23621],
#            dtype='int64')

# %%
"""
list_one: 55 indexes with missing TMDB ID.
list_two: 39 indexes to remove from the dataset.
list_keep_indexes: 16 (55-39) indexes to keep in the dataset and find their official tmdb id.
"""
list_one=[700,1626,1658,2079,3002,4950,5337,5508,6892,7227,8793,9166,13251,14355,14552,14816,15330,15353,15484,15554,15934,16226,16311,16536,16764,17676,17836,17949,18300,18718,18874,19057,20901,20913,21088,21099,21149,21150,21157,21162,21222,21281,21454,21520,21959,22372,22427,22611,22632,22818,22902,23073,23177,23428,23621]
list_two=[5508,7227,8793,9166,14355,14552,15353,15554,15934,16226,16311,16536,16764,17676,17836,17949,18300,18718,18874,19057,20913,21088,21099,21149,21150,21157,21162,21222,21281,21454,21520,21959,22372,22611,22632,22818,23073,23177,23621]
list_keep_indexes=[x for x in list_one if x not in list_two]
list_keep_indexes=[elem for elem in list_keep_indexes if elem not in [2079,3002,22902]]
list_keep_indexes
# Out:
# [700,
#  1626,
#  1658,
#  4950,
#  5337,
#  6892,
#  13251,
#  14816,
#  15330,
#  15484,
#  20901,
#  22427,
#  23428]

# %%
"""
Out of the 55 NaN TMDB ids and after executing the cell above for each of the 55 movies,
we decided that the below 15 movies will be kept and the correct TMDB id will be replaced.
"""
#index 700 - Change title to "Paul Bowles: Half Moon"
dataset_tmdbid_rduplicates.iloc[list_values[0],0]="Paul Bowles: Half Moon"

#index 1626 - Change year of release from 1995 to 1998
dataset_tmdbid_rduplicates.iloc[list_values[1],10]=str(1998)

#index 2079,3002 - Change manually TMDB id
dataset_tmdbid_rduplicates.iloc[list_values[3],14]=68722.0
dataset_tmdbid_rduplicates.iloc[list_values[4],14]=73963.0

#index 6892 - Change year of release to 2003
dataset_tmdbid_rduplicates.iloc[list_values[8],10]=str(2003)

#index 15330 - Change year of release from 1978 to 2009
dataset_tmdbid_rduplicates.iloc[list_values[16],10]=str(2009)

#index 20901 - Change year of release from 2001 to 1999
dataset_tmdbid_rduplicates.iloc[list_values[32],10]=str(1999)

#index 22902 - Change tmdb id to 722616
dataset_tmdbid_rduplicates.iloc[list_values[50],14]=722616.0

# %%
"""
The function to apply on the indexes kept out of those 55 with nan tmdb ids. 
Note that out of the 16 indexes, three of them were excluded because their official TMDB id was manually set. 
For the transformations applied on the 16 indexes see the previous code block.
"""
import numpy as np
def replace_nan_tmdbids(row_index):
    """
    Purpose: Collect the official TMDB id for a movie.
    Arguments: The row of the movie corresponding to its index.
    Output: The collected TMDB id.
    """
    keep_movie_title=dataset_tmdbid_rduplicates.iloc[row_index]["title"] #1
    collected_id=[options['id'] for options in movie.search(keep_movie_title) if (options['title'].lower()==keep_movie_title.lower() and options['release_date'].split('-')[0]==dataset_tmdbid_rduplicates['year'][dataset_tmdbid_rduplicates['title']==keep_movie_title].values[0])] #2
    return float(collected_id[0]) #3

# %%
"""Apply the function above to collect the official TMDB id of the 16 movies without a collected tmdb id."""
dataset_tmdbid_rduplicates["index"]=dataset_tmdbid_rduplicates.index
tqdm.pandas()
dataset_tmdbid_rduplicates["tmdbId"]=dataset_tmdbid_rduplicates["index"].progress_apply(lambda x: replace_nan_tmdbids(x) if x in list_keep_indexes else dataset_tmdbid_rduplicates.iloc[x,14])
# Out:
#   0%|          | 0/48875 [00:00<?, ?it/s]

# %%
"""
The rest 39 indexes(movies) are removed from the whole dataset.
"""
index_to_remove=[5508,7227,8793,9166,14355,14552,15353,15554,15934,16226,16311,16536,16764,17676,17836,17949,18300,18718,18874,19057,20913,21088,21099,21149,21150,21157,21162,21222,21281,21454,21520,21959,22372,22611,22632,22818,23073,23177,23621]
dataset_tmdbid_rduplicates=dataset_tmdbid_rduplicates[~dataset_tmdbid_rduplicates.index.isin(index_to_remove)]
dataset_tmdbid_rduplicates=dataset_tmdbid_rduplicates.reset_index(drop=True)
dataset_tmdbid_rduplicates.shape
# Out:
# (48836, 17)

# %%
array_nonvalid_tmdbids=[]
def get_updated_tmdbid(tmdbid, array_nonvalid_tmdbids):
    """
    Purpose: Update the tmdb IDs per movie from the TMDB API source. For the majority of the movies in the dataset, 
             their TMDB id should much the relative id from the Grouplens dataset. In any different scenario the correct
             id from the API replaces the old one of the Grouplens dataset. The updated ids will be used to extract
             movie's overview text from the TMDB API.
    Arguments: tmdbid -> The movie's id from TMDB database
               array_nonvalid_tmdbids -> This is an array that get updated every time a recorded tmdbi from Grouplens dataset was invalid. 
                                         Using the movie's title and year of release we try to discover the correct tmdbid.
    Outputs: The updated tmdbid of the movie.
    """
    try:
        if(movie.details(movie_id=tmdbid)):
            search_result=movie.details(movie_id=tmdbid).id
        return search_result
    except:
        movie_title=dataset_tmdbid_rduplicates['title'][dataset_tmdbid_rduplicates['tmdbId']==tmdbid].values[0]
        original_titles=[i["original_title"] for i in movie.search(movie_title)]
        print("exception caught at movie:",movie_title,"\n")
        if len(movie.search(movie_title))!=0:
            if movie_title in original_titles:
                search_result=[options['id'] for options in movie.search(movie_title) if (options['title'].lower()==movie_title.lower() and options['release_date'].split('-')[0]==dataset_tmdbid_rduplicates['year'][dataset_tmdbid_rduplicates['title']==movie_title].values[0])]
                if len(search_result)==1:
                    search_result=search_result[0]
                else:
                    search_result=[]
            else:
                search_result=[]
        else:
            search_result=[]
        array_nonvalid_tmdbids.append(tmdbid)
        return search_result

# %%
"""
Movie title: 1066 is dropped from the dataset because the TMDB database does not have sufficient info for that movie
So we expect from 48836 movies to drop to 48835
"""
dataset_tmdbid_rduplicates=dataset_tmdbid_rduplicates[dataset_tmdbid_rduplicates["title"]!="1066"]
dataset_tmdbid_rduplicates.shape
# Out:
# (48835, 17)

# %%
"""
Movie title: The Queen of Spades is dropped from the dataset because the TMDB database does not have sufficient info for that movie
So we expect from 48835 movies to drop to 48834.
"""
dataset_tmdbid_rduplicates=dataset_tmdbid_rduplicates.drop(dataset_tmdbid_rduplicates[(dataset_tmdbid_rduplicates["title"]=="The Queen of Spades") & (dataset_tmdbid_rduplicates["year"]==str(1916))].index)
dataset_tmdbid_rduplicates=dataset_tmdbid_rduplicates.reset_index(drop=True)
dataset_tmdbid_rduplicates.shape
# Out:
# (48834, 17)

# %%
"""Apply the function get_updated_tmdbid() to return a new column with the updated ids per movie."""
from tqdm.notebook import tqdm
tqdm.pandas()
dataset_tmdbid_rduplicates['tmdbid_updated']=dataset_tmdbid_rduplicates.iloc[0:,14].progress_apply(lambda x: get_updated_tmdbid(x, array_nonvalid_tmdbids))
# Out:
#   0%|          | 0/48834 [00:00<?, ?it/s]
# exception caught at movie: Navy Seals
#
# exception caught at movie: Best of the Best
#
# exception caught at movie: Escaflowne: The Movie
#
# exception caught at movie: Ffolkes
#
# exception caught at movie: Rose Red
#
# exception caught at movie: Pride and Prejudice
#
# exception caught at movie: Tinker, Tailor, Soldier, Spy
#
# exception caught at movie: Children of Dune
#
# exception caught at movie: Dune
#
# exception caught at movie: Jesus of Nazareth
#
# exception caught at movie: The Blue and the Gray
#
# exception caught at movie: Smiley's People
#
# exception caught at movie: The Bourne Identity
#
# exception caught at movie: Lonesome Dove
#
# exception caught at movie: Prime Suspect
#
# exception caught at movie: It
#
# exception caught at movie: Prime Suspect 2
#
# exception caught at movie: Return to Lonesome Dove
#
# exception caught at movie: The Stand
#
# exception caught at movie: The Langoliers
#
# exception caught at movie: From the Earth to the Moon
#
# exception caught at movie: Merlin
#
# exception caught at movie: Storm of the Century
#
# exception caught at movie: Joan of Arc
#
# exception caught at movie: The 10th Kingdom
#
# exception caught at movie: The Mists of Avalon
#
# exception caught at movie: Battlestar Galactica
#
# exception caught at movie: Helen of Troy
#
# exception caught at movie: Hitler: The Rise of Evil
#
# exception caught at movie: 'Salem's Lot
#
# exception caught at movie: Powwow Highway
#
# exception caught at movie: The Phantom of the Opera
#
# exception caught at movie: The Many Adventures of Winnie the Pooh
#
# exception caught at movie: Salem's Lot
#
# exception caught at movie: The Thief and the Cobbler
#
# exception caught at movie: Attila
#
# exception caught at movie: Darwin's Nightmare
#
# exception caught at movie: Angels in America
#
# exception caught at movie: A.K.
#
# exception caught at movie: Fingersmith
#
# exception caught at movie: The Temptations
#
# exception caught at movie: Empire Falls
#
# exception caught at movie: When the Levees Broke: A Requiem in Four Acts
#
# exception caught at movie: The Odyssey
#
# exception caught at movie: Human Trafficking
#
# exception caught at movie: Grindhouse
#
# exception caught at movie: Beauty in Trouble
#
# exception caught at movie: Alice in Wonderland
#
# exception caught at movie: Sybil
#
# exception caught at movie: Power of Nightmares, The: The Rise of the Politics of Fear
#
# exception caught at movie: Cashback
#
# exception caught at movie: 10.5: Apocalypse
#
# exception caught at movie: The Prince of Pennsylvania
#
# exception caught at movie: The Andromeda Strain
#
# exception caught at movie: The Colour of Magic
#
# exception caught at movie: John Adams
#
# exception caught at movie: FLCL
#
# exception caught at movie: Tin Man
#
# exception caught at movie: Into the West
#
# exception caught at movie: Farscape: The Peacekeeper Wars
#
# exception caught at movie: Dinotopia
#
# exception caught at movie: Earthsea
#
# exception caught at movie: Nuremberg
#
# exception caught at movie: Dr. Horrible's Sing-Along Blog
#
# exception caught at movie: XIII: The Conspiracy
#
# exception caught at movie: Knights of Bloodsteel
#
# exception caught at movie: Pinchcliffe Grand Prix
#
# exception caught at movie: Roots
#
# exception caught at movie: Heimat - A Chronicle of Germany
#
# exception caught at movie: Lost in Austen
#
# exception caught at movie: Space Odyssey: Voyage to the Planets
#
# exception caught at movie: Meteor
#
# exception caught at movie: The Hunt For Gollum
#
# exception caught at movie: Alice
#
# exception caught at movie: The Thorn Birds
#
# exception caught at movie: MGS: Philanthropy
#
# exception caught at movie: Mysterious Island
#
# exception caught at movie: Wild China
#
# exception caught at movie: Red Riding: 1974
#
# exception caught at movie: Red Riding: 1980
#
# exception caught at movie: Red Riding: 1983
#
# exception caught at movie: Los Bandoleros
#
# exception caught at movie: The Work of Director Michel Gondry
#
# exception caught at movie: Halo Legends
#
# exception caught at movie: The Phantom
#
# exception caught at movie: The Beast
#
# exception caught at movie: If God Is Willing and da Creek Don't Rise
#
# exception caught at movie: Buster Keaton: A Hard Act to Follow
#
# exception caught at movie: Luke and Lucy: The Texas Rangers
#
# exception caught at movie: Steel of Fire Warriors 2010 A.D.
#
# exception caught at movie: The Pillars of the Earth
#
# exception caught at movie: Elizabeth I
#
# exception caught at movie: Emma
#
# exception caught at movie: Family Guy Presents: It's a Trap
#
# exception caught at movie: Connections
#
# exception caught at movie: Mildred Pierce
#
# exception caught at movie: Peculiarities of the National Hunt
#
# exception caught at movie: Jane Eyre
#
# exception caught at movie: Dreamkiller
#
# exception caught at movie: Streets of Laredo
#
# exception caught at movie: Comanche Moon
#
# exception caught at movie: Dead Man's Walk
#
# exception caught at movie: The Trap: What Happened to Our Dream of Freedom
#
# exception caught at movie: Blame
#
# exception caught at movie: Puss in Boots
#
# exception caught at movie: The Sign of Four
#
# exception caught at movie: G.I. Joe: The Revenge of Cobra
#
# exception caught at movie: The Nazis: A Warning from History
#
# exception caught at movie: Broken Trail
#
# exception caught at movie: All Watched Over by Machines of Loving Grace
#
# exception caught at movie: Windfall
#
# exception caught at movie: Casey Jones
#
# exception caught at movie: The Civil War
#
# exception caught at movie: Bag of Bones
#
# exception caught at movie: Appropriate Adult
#
# exception caught at movie: The Scarlet Letter
#
# exception caught at movie: Shadow Kill
#
# exception caught at movie: Walking with Prehistoric Beasts
#
# exception caught at movie: The Barchester Chronicles
#
# exception caught at movie: The War
#
# exception caught at movie: Thomas Jefferson
#
# exception caught at movie: Treasure Island
#
# exception caught at movie: Jekyll
#
# exception caught at movie: Bleak House
#
# exception caught at movie: Endeavour
#
# exception caught at movie: Prime Suspect 3
#
# exception caught at movie: Prime Suspect 6: The Last Witness
#
# exception caught at movie: Prime Suspect: The Lost Child
#
# exception caught at movie: The Age of the Medici
#
# exception caught at movie: The Cigarette Girl of Mosselprom
#
# exception caught at movie: Halo 4: Forward Unto Dawn
#
# exception caught at movie: Jude the Obscure
#
# exception caught at movie: Jazz
#
# exception caught at movie: Les Misérables
#
# exception caught at movie: Human Planet
#
# exception caught at movie: Madagascar
#
# exception caught at movie: Patrice O'Neal: Elephant in the Room
#
# exception caught at movie: Gayby
#
# exception caught at movie: Battlestar Galactica: Blood & Chrome
#
# exception caught at movie: The Blue Angel
#
# exception caught at movie: Frozen Planet
#
# exception caught at movie: Fantomas
#
# exception caught at movie: Death on the Staircase
#
# exception caught at movie: 20,000 Leagues Under the Sea
#
# exception caught at movie: Daniel Deronda
#
# exception caught at movie: Seven Billiard Tables
#
# exception caught at movie: New York: A Documentary Film
#
# exception caught at movie: Hatfields & McCoys
#
# exception caught at movie: Aftershock: Earthquake in New York
#
# exception caught at movie: The Beach Boys: An American Family
#
# exception caught at movie: The Ice House
#
# exception caught at movie: The Count of Monte Cristo
#
# exception caught at movie: The Forsyte Saga
#
# exception caught at movie: Holocaust
#
# exception caught at movie: The Crimson Petal and the White
#
# exception caught at movie: The Story of Maths
#
# exception caught at movie: Shadowlands
#
# exception caught at movie: The Century of the Self
#
# exception caught at movie: Chastity Bites
#
# exception caught at movie: World War II: When Lions Roared
#
# exception caught at movie: The Day of the Doctor
#
# exception caught at movie: Dead Set
#
# exception caught at movie: Bonnie and Clyde
#
# exception caught at movie: State of Play
#
# exception caught at movie: Cats
#
# exception caught at movie: Goliath Awaits
#
# exception caught at movie: Pokémon Origins
#
# exception caught at movie: Generation Kill
#
# exception caught at movie: Nymphomaniac: Volume I
#
# exception caught at movie: Beyoncé: Life Is But a Dream
#
# exception caught at movie: Women in Love
#
# exception caught at movie: Star Wars: Threads of Destiny
# exception caught at movie: 8
#
# exception caught at movie: Cranford
#
# exception caught at movie: Shrek the Musical
#
# exception caught at movie: Going Postal
#
# exception caught at movie: Rosemary's Baby
#
# exception caught at movie: Neverland
#
# exception caught at movie: The Escape Artist
#
# exception caught at movie: Gunbuster
#
# exception caught at movie: 10.5
#
# exception caught at movie: Al-risâlah
#
# exception caught at movie: 2AM: The Smiling Man
#
# exception caught at movie: Centennial
#
# exception caught at movie: Sins
#
# exception caught at movie: Archangel
#
# exception caught at movie: Cambridge Spies
#
# exception caught at movie: King Solomon's Mines
#
# exception caught at movie: Generation War
#
# exception caught at movie: Auschwitz: The Nazis and the 'Final Solution'
#
# exception caught at movie: History of the Eagles
#
# exception caught at movie: Cleopatra
#
# exception caught at movie: Olive Kitteridge
#
# exception caught at movie: Wuthering Heights
#
# exception caught at movie: Long Way Round
#
# exception caught at movie: Pardon Us
#
# exception caught at movie: Street Fighter: Assassin's Fist
#
# exception caught at movie: Jimi Hendrix
#
# exception caught at movie: The Dust Bowl
#
# exception caught at movie: Ascension
#
# exception caught at movie: The Lost Prince
#
# exception caught at movie: The Missing
#
# exception caught at movie: The Kennedys
#
# exception caught at movie: Otakus in Love
#
# exception caught at movie: Daar
#
# exception caught at movie: Frankenstein
#
# exception caught at movie: North and South, Book II
#
# exception caught at movie: Houdini
#
# exception caught at movie: V
#
# exception caught at movie: North and South, Book I
#
# exception caught at movie: V: The Final Battle
#
# exception caught at movie: The Magical Legend of the Leprechauns
#
# exception caught at movie: Noah's Ark
#
# exception caught at movie: The Diary of Anne Frank
#
# exception caught at movie: Pride and Prejudice
#
# exception caught at movie: Merlin's Apprentice
#
# exception caught at movie: Thorne: Sleepyhead
#
# exception caught at movie: Rough Riders
#
# exception caught at movie: Untitled Spider-Man Reboot
#
# exception caught at movie: Heidi
#
# exception caught at movie: The Phantom of the Opera
#
# exception caught at movie: The Sacketts
#
# exception caught at movie: Taken
#
# exception caught at movie: Invasion
#
# exception caught at movie: Thorne: Scaredy Cat
#
# exception caught at movie: Space
#
# exception caught at movie: In Cold Blood
#
# exception caught at movie: Guyana Tragedy: The Story of Jim Jones
#
# exception caught at movie: Rage of Angels
#
# exception caught at movie: Rubber Johnny
#
# exception caught at movie: Li'l Quinquin
#
# exception caught at movie: Dangerous Liaisons
#
# exception caught at movie: Neverwhere
#
# exception caught at movie: Khan Kluay
#
# exception caught at movie: Family Guy Presents: Blue Harvest
#
# exception caught at movie: World War III
#
# exception caught at movie: Fantômas: The Dead Man Who Killed
#
# exception caught at movie: Fantômas: Fantômas Against Fantômas
#
# exception caught at movie: Monty Python: Almost the Truth - Lawyers Cut
#
# exception caught at movie: Casanova
#
# exception caught at movie: Sense & Sensibility
#
# exception caught at movie: A Rumor of War
#
# exception caught at movie: The Tenant of Wildfell Hall
#
# exception caught at movie: Stargate SG-1 Children of the Gods - Final Cut
#
# exception caught at movie: WWII IN HD
#
# exception caught at movie: The Jinx: The Life and Deaths of Robert Durst
#
# exception caught at movie: Anna Karénina
#
# exception caught at movie: The Last Templar
#
# exception caught at movie: Sinatra: All or Nothing at All
#
# exception caught at movie: Halo: Nightfall
#
# exception caught at movie: The Men Who Built America
#
# exception caught at movie: Prime Suspect 5: Errors of Judgement
#
# exception caught at movie: Labyrinth
#
# exception caught at movie: The Sinking of the Laconia
#
# exception caught at movie: Firestarter 2: Rekindled
#
# exception caught at movie: Journey to the Center of the Earth
#
# exception caught at movie: Me Shivajiraje Bhosale Boltoy
#
# exception caught at movie: I, Claudius
#
# exception caught at movie: Afro Samurai
#
# exception caught at movie: Autumn Tale
#
# exception caught at movie: Anne Of Green Gables: The Continuing Story
#
# exception caught at movie: Family Guy Presents: Something, Something, Something, Dark Side
#
# exception caught at movie: Death Comes to Pemberley
#
# exception caught at movie: The Lost Room
#
# exception caught at movie: Star Trek: Renegades
#
# exception caught at movie: Thief
#
# exception caught at movie: Days of Hope
#
# exception caught at movie: Hit & Miss
#
# exception caught at movie: The Blue Planet
#
# exception caught at movie: True Women
#
# exception caught at movie: Snapphanar
#
# exception caught at movie: Sword Art Online Extra Edition
#
# exception caught at movie: Little Dorrit
#
# exception caught at movie: Attack on Titan: Crimson Bow and Arrow
#
# exception caught at movie: The Witches of Oz
#
# exception caught at movie: Pope John Paul II
#
# exception caught at movie: SuckSeed
#
# exception caught at movie: If Tomorrow Comes
#
# exception caught at movie: The Master and Margarita
#
# exception caught at movie: The Secret Life of Marilyn Monroe
#
# exception caught at movie: Seventeen Moments in Spring
#
# exception caught at movie: The Adventures of Sherlock Holmes and Dr. Watson: Bloody Signature
#
# exception caught at movie: Sherlock Holmes and Dr. Watson: Acquaintance
#
# exception caught at movie: Hotel Room
#
# exception caught at movie: Wild Times
#
# exception caught at movie: Dancing on the Edge
#
# exception caught at movie: Weekend of a Champion
#
# exception caught at movie: North Pole: Open For Christmas
#
# exception caught at movie: Atomic Train
#
# exception caught at movie: The Nesting
#
# exception caught at movie: Sinatra
#
# exception caught at movie: Sweet Lies
#
# exception caught at movie: Childhood's End
#
# exception caught at movie: Sherlock: The Abominable Bride
#
# exception caught at movie: The 7:39
#
# exception caught at movie: King
#
# exception caught at movie: The Seventh Company Has Been Found
#
# exception caught at movie: The Bible
#
# exception caught at movie: World Without End
#
# exception caught at movie: Death Note Rewrite: Genshisuru Kami
#
# exception caught at movie: X: Past Is Present
#
# exception caught at movie: Busco Novio Para Mi Mujer
#
# exception caught at movie: War and Peace
#
# exception caught at movie: Jill and Joy
#
# exception caught at movie: Mockingbird Lane
#
# exception caught at movie: Tjorven, Batsman, and Moses
#
# exception caught at movie: Horsing Around
#
# exception caught at movie: And Then There Were None
#
# exception caught at movie: Long Way Down
#
# exception caught at movie: Area 88
#
# exception caught at movie: Restless
#
# exception caught at movie: The Night Manager
#
# exception caught at movie: The Fire Next Time
#
# exception caught at movie: Boys Over Flowers
#
# exception caught at movie: He's Beautiful!
#
# exception caught at movie: 11.22.63
#
# exception caught at movie: A Body to Die For: The Aaron Henry Story
#
# exception caught at movie: Karas: The Prophecy
#
# exception caught at movie: Samurai X : Reflection
#
# exception caught at movie: Blue Submarine No. 6
#
# exception caught at movie: Residue
#
# exception caught at movie: Shaka Zulu
#
# exception caught at movie: To the Ends of the Earth
#
# exception caught at movie: Into the Universe with Stephen Hawking
#
# exception caught at movie: Don't Turn the Other Cheek
#
# exception caught at movie: Kony 2012
#
# exception caught at movie: Louis Theroux: By Reason of Insanity
#
# exception caught at movie: Louis Theroux: Extreme Love - Autism
#
# exception caught at movie: Adolf Hitler: The Greatest Story Never Told
#
# exception caught at movie: Planet Earth
#
# exception caught at movie: Life
#
# exception caught at movie: Monkey Planet
#
# exception caught at movie: Intruders
#
# exception caught at movie: Priest of Evil
#
# exception caught at movie: Deo pa-i-beu
#
# exception caught at movie: Mortal Kombat: Conquest
#
# exception caught at movie: The Far Pavilions
#
# exception caught at movie: Around the World in 80 Days
#
# exception caught at movie: Wyrd Sisters
#
# exception caught at movie: Gormenghast
#
# exception caught at movie: Shado
#
# exception caught at movie: Cold War 2
# exception caught at movie: Jean-Claude Van Johnson
#
# exception caught at movie: Over the Garden Wall
#
# exception caught at movie: Wolf Creek
#
# exception caught at movie: Small Island
#
# exception caught at movie: Horace and Pete
#
# exception caught at movie: Maigret Sets A Trap
#
# exception caught at movie: Sense and Sensibility
#
# exception caught at movie: Jane Eyre
#
# exception caught at movie: Twist of Fate
#
# exception caught at movie: Baseball
#
# exception caught at movie: Crisis in Six Scenes
#
# exception caught at movie: Legally Blonde: The Musical
#
# exception caught at movie: The Way We Live Now
#
# exception caught at movie: The Secret of Crickley Hall
#
# exception caught at movie: Nature's Great Events
#
# exception caught at movie: Political Animals
#
# exception caught at movie: Spies of Warsaw
#
# exception caught at movie: Kickassia
#
# exception caught at movie: Suburban Knights
#
# exception caught at movie: The Spoils of Babylon
#
# exception caught at movie: Le passe-muraille
#
# exception caught at movie: The Capture of the Green River Killer
#
# exception caught at movie: Superheroes: A Never-Ending Battle
#
# exception caught at movie: Maigret's Dead Man
#
# exception caught at movie: Great Migrations
#
# exception caught at movie: Pearl
#
# exception caught at movie: Zombie Fever
#
# exception caught at movie: River
#
# exception caught at movie: Race to Mars
#
# exception caught at movie: The Night Of
#
# exception caught at movie: Prohibition
#
# exception caught at movie: Tess of the D'Urbervilles
#
# exception caught at movie: The Tommyknockers
#
# exception caught at movie: Jason and the Argonauts
#
# exception caught at movie: Band of Brothers
#
# exception caught at movie: Planet Earth II
#
# exception caught at movie: Diamond Cartel
#
# exception caught at movie: Lady Blue Shanghai
#
# exception caught at movie: Inseparable
#
# exception caught at movie: Asylum of Darkness
#
# exception caught at movie: Bangkok Hilton
#
# exception caught at movie: Payback: Straight Up
#
# exception caught at movie: The Dovekeepers
#
# exception caught at movie: Assassin's Creed: Lineage
#
# exception caught at movie: Maigrets Night at the Crossroads
#
# exception caught at movie: Texas Rising
#
# exception caught at movie: Gulliver's Travels
#
# exception caught at movie: The Killing Season
#
# exception caught at movie: BoJack Horseman Christmas Special: Sabrina's Christmas Wish
#
# exception caught at movie: Black Mirror: White Christmas
#
# exception caught at movie: The Keepers
#
# exception caught at movie: A Little Princess
#
# exception caught at movie: The Enfield Haunting
#
# exception caught at movie: Bad Ben
#
# exception caught at movie: Pandora's Box
#
# exception caught at movie: 5ive Days to Midnight
#
# exception caught at movie: Rick and Morty: State of Georgia Vs. Denver Fenton Allen
#
# exception caught at movie: Scribe
#
# exception caught at movie: A History of Horror with Mark Gatiss
#
# exception caught at movie: The Defiant Ones
#
# exception caught at movie: House of Saddam
#
# exception caught at movie: Tsunami: The Aftermath
#
# exception caught at movie: Superman II: The Richard Donner Cut
#
# exception caught at movie: Death on the Nile
#
# exception caught at movie: Murder on the Orient Express
#
# exception caught at movie: Video Game High School
#
# exception caught at movie: The Devil's Whore
#
# exception caught at movie: Happy!
#
# exception caught at movie: The Long Hot Summer
#
# exception caught at movie: Everything is Free
#
# exception caught at movie: Blue Planet II
#
# exception caught at movie: Bad Match
#
# exception caught at movie: Life with Judy Garland: Me and My Shadows
#
# exception caught at movie: Louis Theroux: Extreme Love - Dementia
#
# exception caught at movie: Charlemagne
#
# exception caught at movie: The Victoria's Secret Fashion Show 2014
#
# exception caught at movie: The Victoria's Secret Fashion Show 2013
#
# exception caught at movie: Charles II: The Power & the Passion
#
# exception caught at movie: Code of a Killer
#
# exception caught at movie: Batman: Dead End
#
# exception caught at movie: Sgt Pepper's Musical Revolution with Howard Goodall
#
# exception caught at movie: My Journey Through French Cinema
#
# exception caught at movie: Born of Hope
#
# exception caught at movie: Infoholic
#
# exception caught at movie: Wives and Daughters
#
# exception caught at movie: Godless
#
# exception caught at movie: The Good Witch's Wonder
#
# exception caught at movie: Anne Frank: The Whole Story
#
# exception caught at movie: Making a Murderer
#
# exception caught at movie: The Virgin Queen
#
# exception caught at movie: Maigret in Montmartre
#
# exception caught at movie: National Parks Adventures
#
# exception caught at movie: The Moorside
#
# exception caught at movie: The Last Enemy
#
# exception caught at movie: Little Boy Blue
#
# exception caught at movie: The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
#
# exception caught at movie: Wild Wild Country
#
# exception caught at movie: The Wiggles Movie
#
# exception caught at movie: The Mummy of Tutankhamun
#
# exception caught at movie: Evil Genius: The True Story of America's Most Diabolical Bank Heist
#
# exception caught at movie: Birdsong
#
# exception caught at movie: Dragon Ball Z - The Fall of Men
#
# exception caught at movie: Severus Snape and the Marauders
#
# exception caught at movie: Apple Mac: 1984
#
# exception caught at movie: Kobiety mafii
#
# exception caught at movie: The Silver Chair
#
# exception caught at movie: Prince Caspian and the Voyage of the Dawn Treader
#
# exception caught at movie: The Hounds of Baskerville
#
# exception caught at movie: The Reichenbach Fall
#
# exception caught at movie: Yavarum Nalam
#
# exception caught at movie: Divorce His - Divorce Hers
#
# exception caught at movie: Sekirei
#
# exception caught at movie: Oliver Twist
#
# exception caught at movie: Queen - Rock Montreal
#
# exception caught at movie: Summer Heights High
#
# exception caught at movie: Beastie Boys: Sabotage
#
# exception caught at movie: Prime Suspect: Scent of Darkness
#
# exception caught at movie: Clerks: The Lost Scene
#
# exception caught at movie: Stonemouth
#
# exception caught at movie: Out on a Limb
#
# exception caught at movie: The Take
#
# exception caught at movie: The Master
#
# exception caught at movie: Reilly: Ace of Spies
#
# exception caught at movie: Tut
#
# exception caught at movie: Wonder Woman
#
# exception caught at movie: The Saboteurs
#
# exception caught at movie: L'Allée du Roi
#
# exception caught at movie: Conspiracy of Silence
#
# exception caught at movie: Public Enemies
#
# exception caught at movie: The West
#
# exception caught at movie: Мафия
#
# exception caught at movie: The Sixties
#
# exception caught at movie: New Dominion Tank Police
#
# exception caught at movie: 3x3 Eyes: Legend of the Divine Demon
#
# exception caught at movie: 3x3 Eyes
#
# exception caught at movie: War and Peace
#
# exception caught at movie: Roots
#
# exception caught at movie: Scarlett
#
# exception caught at movie: The Lost Honour of Christopher Jefferies
#
# exception caught at movie: Atop the Fourth Wall: The Movie
#
# exception caught at movie: Occupied - Die Besatzung
#
# exception caught at movie: Persuasion
#
# exception caught at movie: Emma
#
# exception caught at movie: Tanner '88
#
# exception caught at movie: The Game
#
# exception caught at movie: The Charlie Chaplin Festival
#
# exception caught at movie: To Boldly Flee
#
# exception caught at movie: The Case of: JonBenét Ramsey
#
# exception caught at movie: Fish Heads
#
# exception caught at movie: Dumbland
#
# exception caught at movie: A.D. The Bible Continues
#
# exception caught at movie: The Honourable Woman
#
# exception caught at movie: London Spy
#
# exception caught at movie: T2 3-D: Battle Across Time
#
# exception caught at movie: Mythbusters Holiday Special
#
# exception caught at movie: Wolf Hall
#
# exception caught at movie: The Idiot
#
# exception caught at movie: The Adventures of Sherlock Holmes and Doctor Watson: The Hunt for the Tiger
#
# exception caught at movie: Hollywood
#
# exception caught at movie: The Putin Interviews
#
# exception caught at movie: Never Tear Us Apart: The Untold Story of INXS
#
# exception caught at movie: Edge of Darkness
#
# exception caught at movie: The Living Dead: Three Films About The Power of the Past
#
# exception caught at movie: House of Cards
# exception caught at movie: Pole to Pole
#
# exception caught at movie: I Know My First Name Is Steven
#
# exception caught at movie: Carne Y Arena
#
# exception caught at movie: Chinna Gounder
#
# exception caught at movie: Brotherhood of the Rose

# %%
"""
This code block is necessary to print the rows of the dataset that have no equal tmdbid_updated to tmdbid.
This means that their initial tmbdid from Grouplens is not equal to the id the TMDB database has assigned based on title and year of release.
Fortunately, those movies are approximately 511 out of 48833.
"""
import numpy as np
dataset_tmdbid_rduplicates=dataset_tmdbid_rduplicates.reset_index(drop=True)
comparison_column=np.where(dataset_tmdbid_rduplicates["tmdbId"]==dataset_tmdbid_rduplicates["tmdbid_updated"], True, False)
dataset_tmdbid_rduplicates["equal"]=comparison_column
dataset_tmdbid_rduplicates.iloc[0:,:][dataset_tmdbid_rduplicates["equal"]==False]
# Out:
#                                 title                          genres  rating  \
# 3999                       Navy Seals        [Action, Adventure, War]    2.71
# 4353                 Best of the Best                        [Action]    2.97
# 4844            Escaflowne: The Movie  [Action, Adventure, Animation]    3.45
# 4982                          Ffolkes   [Action, Adventure, Thriller]    2.96
# 7263                         Rose Red     [Horror, Mystery, Thriller]    3.21
# ...                               ...                             ...     ...
# 48486                    Pole to Pole        [Adventure, Documentary]    4.00
# 48513  I Know My First Name Is Steven                  [Crime, Drama]    4.00
# 48794                   Carne Y Arena                  [Short, Drama]    2.50
# 48797                  Chinna Gounder      [Drama, Romance, Thriller]    2.50
# 48822         Brotherhood of the Rose                      [Thriller]    3.00
#
#                                    imdb_url  \
# 3999   http://www.imdb.com/title/tt0100232/
# 4353   http://www.imdb.com/title/tt0096913/
# 4844   http://www.imdb.com/title/tt0270933/
# 4982   http://www.imdb.com/title/tt0081809/
# 7263   http://www.imdb.com/title/tt0259153/
# ...                                     ...
# 48486  http://www.imdb.com/title/tt0103514/
# 48513  http://www.imdb.com/title/tt0097553/
# 48794  http://www.imdb.com/title/tt6212516/
# 48797  http://www.imdb.com/title/tt0306644/
# 48822  http://www.imdb.com/title/tt0096985/
#
#                                              reviews_url  \
# 3999   http://www.imdb.com/title/tt0100232/reviews?sp...
# 4353   http://www.imdb.com/title/tt0096913/reviews?sp...
# 4844   http://www.imdb.com/title/tt0270933/reviews?sp...
# 4982   http://www.imdb.com/title/tt0081809/reviews?sp...
# 48513              1.0  I Know My First Name Is Steven Cindy Pickett J...
# 48794              1.0  Carne Y Arena Hector Luis Bustamante Toy Lei C...
# 48797              1.0  Chinna Gounder Salim Ghouse Aachi Manorama Suk...
# 48822              1.0  Brotherhood of the Rose Peter Strauss Robert M...
#
#                        reduced_genres    tmdbId _merge  index tmdbid_updated  \
# 3999         [Action, Adventure, War]   12773.0   both   3999         427910
# 4353                         [Action]   17882.0   both   4353         238751
# 4844   [Action, Adventure, Animation]   68149.0   both   4844             []
# 4982    [Action, Adventure, Thriller]   24549.0   both   4982             []
# 7263      [Horror, Mystery, Thriller]   14980.0   both   7265         788551
# ...                               ...       ...    ...    ...            ...
# 48486        [Adventure, Documentary]  167774.0   both  48527             []
# 48513                  [Crime, Drama]   61693.0   both  48554             []
# 48794                         [Drama]  524475.0   both  48835             []
# 48797      [Drama, Romance, Thriller]  344115.0   both  48838          78983
# 48822                      [Thriller]  540387.0   both  48863             []
#
#        equal
# 3999   False
# 4353   False
# 4844   False
# 4982   False
# 7263   False
# ...      ...
# 48486  False
# 48513  False
# 48794  False
# 48797  False
# 48822  False
#
# [511 rows x 19 columns]

# %%
dataset_tmdbid_rduplicates.shape
# Out:
# (48834, 19)

# %%
"""Run once to save (serialize) the dataset with the updated tmdbids in local disk"""
joblib.dump(dataset_tmdbid_rduplicates, "dataset_updated_tmdbid_18022021.pkl")
dataset_overview=dataset_tmdbid_rduplicates.copy()
dataset_overview.shape
# Out:
# (48834, 19)

# %%
"""For the next function to work properly it's imperative to change the data type of tmdbid_updated column from integer to float."""
dataset_overview["tmdbid_updated"]=dataset_overview["tmdbid_updated"].apply(lambda x: float(x) if x!=[] else x)

# %%
array_empty_overview=[]
def get_overview(tmdbid, array_empty_overview):
    """
    Purpose: Extract the overview text of a movie based on its assigned tmdb id from TMDB API.
             The overview text of a movie will be combined to its plot summary from IMDB database. The latter is already extracted.
    Arguments: tmdbid -> The movie's id from TMDB database
               array_empty_overview -> Collect the ids with no recorded overview text.
    Outputs: The overview text of the movie as officially written in the TMDB API.
    """
    try:
        if(tmdbid!=[]):
            assert type(tmdbid)==float
            search_result=movie.details(movie_id=tmdbid).overview
        else:
            search_result=" "
            pass
        return search_result
    except:
        movie_title=dataset_overview['title'][dataset_overview['tmdbid_updated']==tmdbid].values[0]
        print("exception caught at movie:",movie_title,"\n")
        search_result=" "
        array_empty_overview.append(tmdbid)
        return search_result

# %%
"""
Apply the function get_overview() to retrieve the official overview text per movie from the TMDB database. 
Note that for movies without a valid tmdbid (i.e []) an empty string represents their overview.
"""
dataset_overview["overview"]=dataset_overview.iloc[0:,17].progress_apply(lambda x: get_overview(x, array_empty_overview))
# Out:
#   0%|          | 0/48834 [00:00<?, ?it/s]
# exception caught at movie: Kickassia
#
# exception caught at movie: Suburban Knights
#
# exception caught at movie: To Boldly Flee

# %%
from tqdm.notebook import tqdm
"""Save the dataset with the overview text extracted per movie."""
#joblib.dump(dataset_overview,"dataset_overview_18022021.pkl")
dataset_overview=joblib.load("dataset_overview_18022021.pkl")

# %%
"""
Before proceeding to the next part, Data tokenization & transformation for NLP applications, we should perfrom 3 tasks.
Task 1: Replace the information of the movies "The Master", "Creature" with new details corresponding to different movies that those already imported in the dataset.
Doing a research on movies with a non-valid tmdbid we decided that some of them should be dropped from the dataset, while the title of some others were kept but their content was replaced.
Content is: actors, plot, reviews, imdb_rating, directors
"""
#Task 1: Bring info about two movies: The Master, Creature
from bs4 import BeautifulSoup
import requests
import re

#URL links to IMDB
the_master_link="http://www.imdb.com/title/tt1560747/"
creature_link="http://www.imdb.com/title/tt1686018/"
content_links=[the_master_link,creature_link]

reviews_master_link=the_master_link+"reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0"
reviews_creature_link=creature_link+"reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0"
reviews_links=[reviews_master_link,reviews_creature_link]

content_html=[requests.get(i) for i in content_links]
reviews_html=[requests.get(i) for i in reviews_links]

content_soup=[BeautifulSoup(i.text) for i in content_html]
reviews_soup=[BeautifulSoup(i.text) for i in reviews_html]

"""
Field 1: Extract plot summary
"""
myfield_plot = []
plot_summary = []
index_to_remove_no_plot = []

[myfield_plot.append(i.find_all('div', {'class':'plot_summary'})) for i in tqdm(content_soup, desc="Plot Summary")]
[[[plot_summary.append(y.text) for y in x.find_all('div', {'class':'summary_text'})] for x in i] if len(i) !=0 else index_to_remove_no_plot.append(myfield_plot.index(i)) for i in myfield_plot]
print("Length of the list with Movies that don't have plot summary: {}".format(len(index_to_remove_no_plot)))
if len(index_to_remove_no_plot) == 0:
    print("None of the movie miss plot")
else:
    print("Indexes to remove: {}".format(index_to_remove_no_plot))

"""
Field 2: Extract actors
"""
myfield_cast = []
phase_two = []
phase_three = []
actors_list = []
index_to_remove_no_actors = []

[myfield_cast.append(i.find_all('table', {'class':'cast_list'})) for i in tqdm(content_soup, desc="Actors")]
r_one = re.compile(".*name")
[[phase_two.append(j.find_all('a', {'href':r_one})) for j in i] for i in myfield_cast]
[phase_three.append(phase_two[i][1::2]) for i in range(len(phase_two))]
[actors_list.append(list(map(lambda x: x.text.strip(' ').replace('\n', ''), actors))) for actors in phase_three]            
index_to_remove_no_actors = [i for i,x in enumerate(myfield_cast) if not x]
print("Length of the list with Movies that don't have actors: {}".format(len(index_to_remove_no_actors)))
if len(index_to_remove_no_actors) == 0:
    print("None of the movie miss actors")
else:
    print("Indexes to remove: {}".format(index_to_remove_no_actors))

"""
Field 3: Extract director name(s)
"""
myfield_director = []
director_name = []
index_to_remove_no_directors = []

[myfield_director.append(i.find_all('div', {'class':'plot_summary'})) for i in tqdm(content_soup, desc="Director names")]
r_name = re.compile(".*name")
[[director_name.append(j.find_all('a', {'href':r_name})) for j in i] for i in myfield_director]
director_names = [item[0].text for item in director_name if len(item)!=0]
index_to_remove_no_directors = [i for i,x in enumerate(myfield_director) if not x]
print("Length of the list with Movies that don't have directors: {}".format(len(index_to_remove_no_directors)))
if len(index_to_remove_no_directors) == 0:
    print("None of the movie miss directors")
else:
    print("Indexes to remove: {}".format(index_to_remove_no_directors))

"""
Field 4: Extract imdb movie rating
"""
myfield_rating = []
ratings = []
index_to_remove_no_rating = []

[myfield_rating.append(i.find_all('div', {'class':'ratingValue'})) for i in tqdm(content_soup, desc="IMDB rating")]
[[[ratings.append(y.text) for y in x.find_all('span', {'itemprop':'ratingValue'})] for x in i] for i in myfield_rating]
index_to_remove_no_rating = [i for i,x in enumerate(myfield_rating) if not x]
print("Length of the list with Movies that are not rated: {}".format(len(index_to_remove_no_rating)))
if len(index_to_remove_no_rating) == 0:
    print("None of the movie miss ratings")
else:
    print("Indexes to remove: {}".format(index_to_remove_no_rating))

"""
Field 5: Extract movie reviews
"""
myfield_review_step_one = []
myfield_review_step_two = []
myfield_review_step_three = []

[myfield_review_step_one.append(i.find_all('div', {'class':'lister-list'})) for i in tqdm(reviews_soup, desc="User reviews")]
[[myfield_review_step_two.append(j.find_all('div', {'class':'text show-more__control'})) for j in i] for i in myfield_review_step_one]
[myfield_review_step_three.append(list(map(lambda x: x.text, reviews))) for reviews in myfield_review_step_two]
index_to_remove_no_review = [i for i,x in enumerate(myfield_review_step_one) if not x]
print("Length of the list with Movies that don't have reviews: {}".format(len(index_to_remove_no_review)))
if len(index_to_remove_no_review) == 0:
    print("None of the movies miss reviews")
else:
    print("Indexes to remove: {}".format(index_to_remove_no_review))
# print([i for i,x in enumerate(myfield_review_step_one) if not x])
# print([i for i,x in enumerate(myfield_review_step_two) if not x])
# print([i for i,x in enumerate(myfield_review_step_three) if not x])
# Out:
# Plot Summary:   0%|          | 0/2 [00:00<?, ?it/s]
# Length of the list with Movies that don't have plot summary: 0
# None of the movie miss plot
# Actors:   0%|          | 0/2 [00:00<?, ?it/s]
# Length of the list with Movies that don't have actors: 0
# None of the movie miss actors
# Director names:   0%|          | 0/2 [00:00<?, ?it/s]
# Length of the list with Movies that don't have directors: 0
# None of the movie miss directors
# IMDB rating:   0%|          | 0/2 [00:00<?, ?it/s]
# Length of the list with Movies that are not rated: 0
# None of the movie miss ratings
# User reviews:   0%|          | 0/2 [00:00<?, ?it/s]
# Length of the list with Movies that don't have reviews: 0
# None of the movies miss reviews

# %%
"""
Continue task 1
Extract also the year and the genre of the movies.
"""
year_value=[movie.details(68722.0).release_date.split("-")[0],movie.details(73963.0).release_date.split("-")[0]]
genres_value=[[movie.details(68722.0).genres[0]['name']],[movie.details(73963.0).genres[0]['name']]]

# %%
"""Clean the plot summary and reviews extracted for the new movies"""
plot_summary_cleaned=[re.sub(' +', ' ',plot_text.strip().replace(',', ', ').replace('.', '. ').replace('?', '? ').replace('!', '! ').replace('\n                    See full summary\xa0»', '').rstrip()) for plot_text in plot_summary]
reviews_cleaned=[list(map(lambda x: re.sub(' +', ' ', x.strip().replace(',', ', ').replace('.', '. ').replace('?', '? ').replace('!', '! ').replace('\n                    See full summary\xa0»', '').rstrip()), reviews)) for reviews in myfield_review_step_three]

# %%
"""Finally replace the extracted values for the movies 'The Master' and 'Creature'"""
dataset_overview.iloc[2079,1]=[genres_value[0]] #it's imperative the genres to be a list for the notebooks to come
dataset_overview.iloc[3002,1]=[genres_value[1]] #it's imperative the genres to be a list for the notebooks to come

dataset_overview.iloc[2079,3]=content_links[0]
dataset_overview.iloc[3002,3]=content_links[1]

dataset_overview.iloc[2079,4]=reviews_links[0]
dataset_overview.iloc[3002,4]=reviews_links[1]

dataset_overview.iloc[2079,5][0:len(dataset_overview.iloc[2079,5])]=actors_list[0][0:len(dataset_overview.iloc[2079,5])]
dataset_overview.iloc[3002,5][0:len(dataset_overview.iloc[3002,5])]=actors_list[1][0:len(dataset_overview.iloc[3002,5])]

dataset_overview.iloc[2079,6]=plot_summary_cleaned[0]
dataset_overview.iloc[3002,6]=plot_summary_cleaned[1]

dataset_overview.iloc[2079,7]=ratings[0]
dataset_overview.iloc[3002,7]=ratings[1]

dataset_overview.iloc[2079,8]=director_names[0]
dataset_overview.iloc[3002,8]=director_names[1]

dataset_overview.iloc[2079,9][0:len(dataset_overview.iloc[2079,9])]=reviews_cleaned[0][0:len(dataset_overview.iloc[2079,9])]
dataset_overview.iloc[3002,9][0:len(dataset_overview.iloc[3002,9])]=reviews_cleaned[1][0:len(dataset_overview.iloc[3002,9])]

dataset_overview.iloc[2079,10]=year_value[0]
dataset_overview.iloc[3002,10]=year_value[1]

dataset_overview.iloc[2079,13]=[genres_value[0]]
dataset_overview.iloc[3002,13]=[genres_value[1]]

# %%
"""Task 2 is executed in order to combine the plot summary and overview text per movie into 1 corpus"""
dataset_plot_overview=dataset_overview.copy()
dataset_plot_overview["plot_overview"]=dataset_plot_overview.apply(lambda x: x["plot"] if (x["overview"]==" " or len(x["plot"])>len(x["overview"])) else x["overview"], axis=1)

# %%
"""Task 3 is executed to exploit three reviews for movies with at least three reviews."""
dataset_plot_overview["reviews_enriched"]=dataset_plot_overview["reviews"].apply(lambda x: " ".join(x[0:3]) if len(x)>=3 else " ".join(x[0:2]) if len(x)==2 else x[0])

# %%
"""
Print the rows of the dataframe with two reviews. 
This code block is only for demonstration purposes and can provide an easy way to filter cells with list content.
"""
dataset_plot_overview[dataset_plot_overview["reviews"].map(len)==1]
# Out:
#                                                   title  \
# 55                              Kids of the Round Table
# 106                                             Catwalk
# 139                                             Shadows
# 399    Brother Minister: The Assassination of Malcolm X
# 615                                         Asfour Stah
# ...                                                 ...
# 48807                                           Kaloyan
# 48809                 Parakalo, gynaikes, min klaite...
# 48811                                    Première année
# 48825                                     The Happy Sad
# 48827                                    Burn Your Name
#
#                               genres  rating  \
# 55     [Adventure, Children, Comedy]    2.06
# 106                    [Documentary]    3.04
# 139                          [Drama]    3.06
# 399                    [Documentary]    3.32
# 615                          [Drama]    3.27
# ...                              ...     ...
# 48807               [Drama, History]    2.75
# 48809                [Comedy, Drama]    3.50
# 48811                        [Drama]    1.17
# 48825               [Drama, Romance]    3.00
# 48827               [Drama, Romance]    1.00
#
#                                    imdb_url  \
# 55     http://www.imdb.com/title/tt0113541/
# 55                                                                                                                                                                                                                                                                                                                                                                                                                                           Set in modern times, Alex finds King Arthur's sword Excalibur and must prove himself worthy of it.
# 106                                                                                                                                                                                                                                                                                                                                                                                                                        A documentary following Christy Turlington and other models during spring fashion week in Milan, Paris and New York.
# ...
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 48807                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           For me Kaloyan is a greatly underestimated achievement of Bulgarian cinema, perhaps because its generation could not appreciate its advantages - one expects to see just a war movie that shows how great this Bulgarian tzar was (and he certainly was). However this movie is not just a lesson in History - it makes you be Kaloyan, feel his emotions, think the way he thinks. His character is realistic as well - equally fair and brutal, which a real leader had to be. The story is complex and dynamic as it also features minor characters (in terms of history); the music is suitable and the battle scenes are well made. Its atmosphere is certainly memorable. I consider the film as obligatory for Bulgarian movie fans; personally I prefer it to Aszparuh.
# 48809                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             This 1992 film was directed by Stavros Tsiolis and Christos Vakalopoulos who unfortunately died of cancer a little time later. The film tells the story of a painter of religious paintings and his apprentice who are hired by the town council of a small town in the Greek province to restore the paintings of their church. The painter and his apprentice begin their journey, arrive to the town, meet with all kinds of people, make philosophic conversations, do almost everything except getting their job done, but this doesn't matter at all. As the Greek poet Kostas Kavafis writes in his poem "Ithaki". what is important is not reaching the destination but the journey itself. This is exactly the case in the film. There is a strong comic aura in the film and the plot flows smoothly without the film becoming boring or "pseudo-sophisticated", something that was happening in most of the Greek films of the 80's and early 90's. This film reconciled me with the Greek cinema.
# 48811                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            That's a purely medical student study movie, made by a former doctor, who lnows what he's talking about. the tale of a friendship between two students with its ups and downs. A very good character study, which also shows what medical students life is actually is. Also a beautiful friendship story pulled by a solid ending. An ending about sacrifice.
# 48825                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Should have been called The Miserably Sad since there is nary a whiff of happiness in this exercise in bitterness. Who is audience for it supposed to be? Self hating gays? Unhappy heterosexuals? Miserable bisexuals? Selfish jackasses? If so than they hit the nail on the head but if their target audience was discriminating viewers the makers of this picture must have been sorely disappointed, as anybody unfortunate enough to see this will be too. Badly written, poorly acted by most of the cast amateurishly shot and with a callous attitude towards its characters there ISN'T something here for anyone.
# 48827                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         I watched this film knowing it was not high budget . If you look at as a smaller endeavor without "A" List actors and just focus on what it is you will not be disappointed. Also it's on prime video so it is priced well. . . .
#
# [3263 rows x 22 columns]

# %% [markdown]
# #### -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --

# %% [markdown]
# ### Section 2.1.2
# To follow through this section you are advised to read the comments on top of each code block.

# %%
"""The section is currently empty. We plan to periodically add more movies and genres in the dataset"""
# Out:
# 'The section is currently empty. We plan to periodically add more movies and genres in the dataset'

# %% [markdown]
# #### -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --

# %%
"""Version with all columns included-Serialize the dataset that will be used in part 3.1 for data tokenization and transformation."""
joblib.dump(dataset_plot_overview,'dataset_part_3.1_22022021.pkl')
# Out:
# ['dataset_part_3.1_22022021.pkl']

# %%
"""Drop unnecessary columns that won't be used in notebooks to come."""
dataset_plot_overview.drop(["_merge", "index", "equal"], axis=1, inplace=True)

# %%
"""Light Version with only the necessary columns included-Serialize the dataset that will be used in part 3.1 for data tokenization and transformation."""
joblib.dump(dataset_plot_overview,'dataset_part_3.1_22022021_light.pkl')
# Out:
# ['dataset_part_3.1_22022021_light.pkl']

# %% [markdown]
# #### THIS IS THE END OF PART 2.1 - Correcting & Enriching the dataset
